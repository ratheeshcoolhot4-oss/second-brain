# %%
my_var_1 = '10'
my_var_2 = '10'
print(f" The id for my_var_1 {id(my_var_1)}")
print(f" The id for my_var_1=2 {id(my_var_2)}")
# Out:
#  The id for my_var_1 4350778416
#  The id for my_var_1=2 4350778416

# %%
my_var_1 = '10'
my_var_2 = '20'
print(f" The id for my_var_1 {id(my_var_1)}")
print(f" The id for my_var_1=2 {id(my_var_2)}")
# Out:
#  The id for my_var_1 4350778416
#  The id for my_var_1=2 4363845104
